# %%
# Install UCI ML Repo package
# !pip install ucimlrepo --quiet

# %%
# Import all necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as r

from ucimlrepo import fetch_ucirepo
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
# Load Wine dataset from UCI
wine_data = fetch_ucirepo(id=186)

# Features and targets
X_all = wine_data.data.features
y_all = wine_data.data.targets.squeeze().astype(int)  # Convert to int

# %%
# Define parameter space and setup logs
kernelList = ['linear', 'poly', 'rbf', 'sigmoid']
overall_results = []
best_overall_accuracy = 0
best_sample_log = None

# For reproducibility
r.seed(42)

# %%
import time

# Use only stable kernels first — add back others once stable
kernelList = ['linear', 'rbf']
overall_results = []
best_overall_accuracy = 0
best_sample_log = None

for sample_no in range(10):
    print(f"\n🔁 Processing Sample {sample_no}...")

    # Split data into train/test sets
    X_train_full, X_test, y_train_full, y_test = train_test_split(
        X_all, y_all, test_size=0.3, random_state=sample_no)

    # Select only 50 training rows
    X_train = X_train_full.sample(n=50, random_state=sample_no)
    y_train = y_train_full.loc[X_train.index]

    X_train = X_train.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)

    # Track best performance for this sample
    bestAccuracy = 0
    bestKernel = ""
    bestC = 0
    bestGamma = 0
    iteration_log = []

    for i in range(100):
        kernel = r.choice(kernelList)
        C = round(r.uniform(0.5, 5.0), 2)         # safer range
        gamma = round(r.uniform(0.01, 0.5), 3)    # avoid extremes

        try:
            model = SVC(kernel=kernel, C=C, gamma=gamma)

            # ⏱️ Time training
            start = time.time()
            model.fit(X_train, y_train)
            fit_time = time.time() - start

            # Skip if taking too long
            if fit_time > 3:
                print(f"⏳ Skipped slow model at iteration {i} (took {fit_time:.2f}s)")
                continue

            preds = model.predict(X_test)
            acc = accuracy_score(y_test, preds) * 100

        except Exception as e:
            print(f"⚠️ Error at iteration {i}: {e}")
            acc = 0

        if acc > bestAccuracy:
            bestAccuracy = acc
            bestKernel = kernel
            bestC = C
            bestGamma = gamma

        if i % 10 == 0:
            iteration_log.append({
                'Iteration': i,
                'Fitness (bestAccuracy)': round(bestAccuracy, 4),
                'bestKernel': bestKernel,
                'bestC': bestC,
                'bestGamma': bestGamma,
                'sample_no': sample_no
            })

    # Store results for this sample
    overall_results.append({
        'Sample': sample_no,
        'BestAccuracy': round(bestAccuracy, 4),
        'Kernel': bestKernel,
        'C': bestC,
        'Gamma': bestGamma
    })

    # Track best overall sample
    if bestAccuracy > best_overall_accuracy:
        best_overall_accuracy = bestAccuracy
        best_sample_log = pd.DataFrame(iteration_log)
# Out:
# 🔁 Processing Sample 0...
#
# 🔁 Processing Sample 1...
#
# 🔁 Processing Sample 2...
#
# 🔁 Processing Sample 3...
#
# 🔁 Processing Sample 4...
#
# 🔁 Processing Sample 5...
#
# 🔁 Processing Sample 6...
#
# 🔁 Processing Sample 7...
#
# 🔁 Processing Sample 8...
#
# 🔁 Processing Sample 9...

# %%
# Plot convergence graph for best sample
plt.figure(figsize=(10, 5))
plt.plot(best_sample_log['Iteration'], best_sample_log['Fitness (bestAccuracy)'], marker='o', linestyle='-', color='darkorange')
plt.title('Convergence Plot for Best Sample (50-row Training)', fontsize=14)
plt.xlabel('Iteration')
plt.ylabel('Best Accuracy (%)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Optional: Save overall results to CSV
results_df = pd.DataFrame(overall_results)
results_df.to_csv("svm_optimization_results.csv", index=False)

# Show top results
results_df.sort_values(by='BestAccuracy', ascending=False).head()
# Out:
#    Sample  BestAccuracy  Kernel     C  Gamma
# 8       8       48.2051  linear  0.58  0.012
# 7       7       46.9231  linear  2.77  0.322
# 5       5       46.0000  linear  2.10  0.471
# 9       9       45.7949  linear  0.51  0.184
# 2       2       44.9231     rbf  3.11  0.478
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Sample'].plot(kind='hist', bins=20, title='Sample')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['BestAccuracy'].plot(kind='hist', bins=20, title='BestAccuracy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['C'].plot(kind='hist', bins=20, title='C')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Gamma'].plot(kind='hist', bins=20, title='Gamma')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Kernel').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Sample', y='BestAccuracy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='BestAccuracy', y='C', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='C', y='Gamma', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Sample'].plot(kind='line', figsize=(8, 4), title='Sample')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['BestAccuracy'].plot(kind='line', figsize=(8, 4), title='BestAccuracy')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['C'].plot(kind='line', figsize=(8, 4), title='C')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Gamma'].plot(kind='line', figsize=(8, 4), title='Gamma')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['Kernel'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='Sample', y='Kernel', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['Kernel'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='BestAccuracy', y='Kernel', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['Kernel'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='C', y='Kernel', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['Kernel'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='Gamma', y='Kernel', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
